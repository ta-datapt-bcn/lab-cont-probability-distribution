# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.26853497 2.47760416 2.05361723 2.13975094 2.31603155 2.3122273
#  2.5302154  2.34001809 2.96644641 2.68772049]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.

# %%
# your code here
def random_numbers(bottom,ceiling,count):
    distribution=uniform.rvs(size=count)
    randoms=bottom+(ceiling-bottom)*distribution
    return randoms

# %%
d_1=random_numbers(10,15,100)
print('Distribution 1:',d_1)
print(' ')
print('-------------------------------------------------------------------')
print(' ')
d_2=random_numbers(10,60,1000)
print('Distribution 2:',d_2)
# Out:
# Distribution 1: [12.69708535 10.29139187 14.6755566  11.00142874 14.79437332 14.07771896
#  14.47402097 11.4299274  13.80795301 13.05164804 12.35218786 10.94651406
#  12.5349908  13.75671298 14.65311515 10.57820065 12.97835667 14.24124455
#  14.12884117 12.34382288 11.90458251 11.73655195 13.29609865 12.30273369
#  11.02537735 10.85596083 12.15407225 11.89927747 13.3994677  12.21113269
#  10.12973789 10.41713529 13.81350739 13.97518856 10.14091522 12.49694101
#  11.00911648 11.08723607 12.82675264 13.87950494 11.19496705 10.33776373
#  11.75394393 14.98966534 12.32923796 11.38578425 13.44612004 11.33299473
#  11.98721778 12.36119541 10.97165222 13.52545708 14.64247074 14.45017133
#  14.08023846 10.40083262 12.45205448 12.04881021 13.46988923 11.58827317
#  11.75047049 14.14058265 14.30712202 13.02221577 14.36000178 10.78066943
#  10.89144595 12.43754495 14.2539496  11.19824375 12.29447205 11.79343673
#  12.87274471 10.65190766 13.81236006 14.46231118 12.77082845 14.79992656
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# How are the two distributions different?

# %%
fig,ax=plt.subplots(1,2)
sns.histplot(d_1,bins=10,ax=ax[0]).set_title('d_1')
sns.histplot(d_2,bins=10,ax=ax[1],color='red').set_title('d_2')
# Out:
# Text(0.5, 1.0, 'd_2')

# %%
# X-axis depending on ceiling, number of obs in each bin depending on n

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.

# %%
import scipy.stats as stats
sample_1 = stats.norm(10,1).rvs(1000)
sample_1.mean()
# Out:
# 9.996762462958278

# %%
sample_2=stats.norm(10,50).rvs(1000)
sample_2
# Out:
# array([-1.42717618e+01,  1.06192652e+02, -2.34738506e+01,  8.18906002e+01,
#        -4.47790107e+01,  8.25757969e+01,  5.56930273e+01,  8.23531173e+01,
#         4.39632032e+01,  1.24374327e+02, -6.14412002e+01, -1.41176196e+01,
#         3.49240357e+01,  5.64042632e+00,  1.18084064e+01, -1.35085958e+01,
#        -7.87961465e+00, -8.97457419e+01,  5.45522492e+01,  3.36322343e+01,
#         6.18563890e+01, -3.76211057e+01,  2.89547487e+01,  2.14337288e+01,
#         4.51043432e+00, -5.57935251e+01,  4.23008782e+01, -2.12854758e+01,
#         3.70869122e+01,  1.06191011e+01, -1.24729311e+01, -4.56133320e+01,
#        -2.53597320e+01,  6.63312656e+01,  6.80291588e+01,  2.75301258e+01,
#        -4.21177557e+01,  4.82299202e+01,  5.44548288e+00, -2.25411316e+01,
#         6.07525362e+01,  3.85780335e+01,  4.65982572e+00, -2.68308887e+01,
#         4.90368316e+01,  2.57078573e+01,  3.89964796e+01, -2.96495009e+01,
# ...

# %% [markdown]
# How are the two distributions different?

# %%
# different distrubiton around the mean (x-axis)

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
sns.histplot(df['Fuel Barrels/Year'],bins=50)
# Out:
# <AxesSubplot:xlabel='Fuel Barrels/Year', ylabel='Count'>

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(df['CO2 Emission Grams/Mile'],bins=50)
# Out:
# <AxesSubplot:xlabel='CO2 Emission Grams/Mile', ylabel='Count'>

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(df['Combined MPG'],bins=50)
# Out:
# <AxesSubplot:xlabel='Combined MPG', ylabel='Count'>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# barrels & emission relatively normal, MPG left skew
# Because of the bell shape of the curve

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.

# %%
exp_sample1=np.random.exponential(10,100) #np.random.exponential(mean,size)
exp_sample1.mean()
# Out:
# 9.772027886449973

# %%
def exp_sample(mean,size):
    exp_dist=np.random.exponential(mean,size)
    return exp_dist

# %%
exp_sample1=exp_sample(10,100)
exp_sample1

exp_sample2=exp_sample(10,1)
exp_sample2
# Out:
# array([9.94333265])

# %%
fig,ax=plt.subplots(1,2)
sns.histplot(exp_sample1,bins=10,ax=ax[0]).set_title('exp_dist1')
sns.histplot(exp_sample2,bins=10,ax=ax[1],color='red').set_title('exp_dist2')
# Out:
# Text(0.5, 1.0, 'exp_dist2')

# %% [markdown]
# How are the two distributions different?

# %%
# no variation can be see when size =1

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# Hint: This is same as saying P(x<15)
from scipy.stats import expon

real_data = expon(scale=10)
real_data_less15 = real_data.cdf(15)
real_data_less15
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
real_data_more15 = real_data.sf(15)
real_data_more15
# Out:
# 0.22313016014842982
