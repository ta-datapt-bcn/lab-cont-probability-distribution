# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
from scipy import stats;
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Challenge 1 - Generate and Plot Normal Distributions

# %% [markdown]
# #### Step 1: Generate samples and test normal distribution
#
# Use mean = 50, standard_deviation = 5 and sample_size=[10, 50, 500, 5000] to generate 4 random samples that are normally distributed. Test your normal distributions with [`scipy.stats.normaltest`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html).
#
#
# *Hint: Read the documentation for `scipy.stats.normaltest`. The function does not simply return Yes or No for whether your data is normal distribution. It returns the likelihood.*

# %%
# Variables
mu = 50;
sigma = 5;
sample_size = [10, 50, 500, 5000]

# Distributions & Tests
dists = [np.random.normal(mu, sigma, size) for size in sample_size]
tests = [stats.normaltest(dist) for dist in dists]

# Show tests
tests
# Out:
# [NormaltestResult(statistic=1.756734988265188, pvalue=0.4154606002333623),
#  NormaltestResult(statistic=0.5666462550985789, pvalue=0.7532763441911213),
#  NormaltestResult(statistic=2.737712643163751, pvalue=0.2543977424477014),
#  NormaltestResult(statistic=0.1519019250492653, pvalue=0.9268616564006451)]

# %% [markdown]
# #### Interpret the normaltest results and make your observations.

# %% [markdown]
# `Comments:`

# %% [raw]
# En todos aparece un pvalue > 0.05, por lo que se puede concluir que son distribuciones normales. Normalmente, a mayor número de muestras, más normal debería ser la distribución por la teoría de los grandes números.

# %% [markdown]
# #### Step 2: Plot normal distributions
#
# Use matplotlib subplots to plot a histogram of each sample.
#
# *Hints:*
# - Use subplots to compare your figures side by side.
#
# - Your output should look like below:
#
# ![normal distributions with different sample sizes](images/ch-1.png)

# %%
# Creamos la lista de nuevo porque usaremos .pop() y así no modificamos la original

numbers = [a for a in dists]
samples = [a for a in sample_size]

# %%
# Ignoramos warnings porque usaremos distplot

import warnings
warnings.filterwarnings('ignore')

# %%
# Create figure and axes
fig, ax = plt.subplots(2,2, figsize=(20,12))

# Usaremos distplot

# Plot each histogram
for i in (0,1):
    for j in (0,1):
        sns.distplot(numbers.pop(0), ax=ax[i][j]).set_title(f'Sample size = {samples.pop(0)}')

# %% [markdown]
# #### Compare the distributions above. What do you observe? Explain with the Central Limit Theorem.

# %% [markdown]
# `Comments:` Cuanto mayor es el número de muestras, más semejanza a la distribución teórica, en este caso la normal.
#
# El teorema central del límite demuestra que las medias de las muestras tiende a la media de la distribución teórica.
#
# A continuación vemos cómo la media se va acercando a la teórica (mu = 50) cuanto mayor es el número de muestras.

# %%
for a in range(4):
    print(f'Sample size {sample_size[a]}; mean {np.mean(dists[a])}')
# Out:
# Sample size 10; mean 53.74909756461587
# Sample size 50; mean 49.75899092447528
# Sample size 500; mean 50.25439151411831
# Sample size 5000; mean 50.02816848016025

# %% [markdown]
# # Challenge 2 - Plot Probability Mass Function (PMF)

# %% [markdown]
# #### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# #### Question: We assume that the probability of clicking an Ad in a Youtube video is 0.15. We have a sample of 5 people who watched the video and we want to plot the PMF for a binomial distribution.
#
# *Hint: use binom from `scipy.stats.binom`. Your output should look like below:*
#
# ![binom 10](images/ch-2.png)

# %%
# Variables 
p = 0.15
n = 5

# Binomial distribution

youtube = stats.binom(n,p)

# Plot line + bullet point -> Discrete Distribution Representation
x = np.arange(youtube.ppf(0.001),
              youtube.ppf(0.999))
fmp = youtube.pmf(x)
_ = plt.plot(x, fmp)

# %% [markdown]
# #### Explain what you observe from the plot above.

# %% [markdown]
# `Comments:`

# %% [raw]
# La probabilidad es tan baja que lo más probable es que 0/5 personas hagan click en el anuncio. A medida que aumenta el número de personas, la probabilidad de que éstas hagan click va descendiendo, dejando la probabilidad de que 4/5 ó 5/5 personas hagan click en prácticamente residual.

# %% [markdown]
# #### Now plot PMP with 50, 500, and 5000 visitors.

# %%
# Create figure and axes
fig, ax = plt.subplots(3,1, figsize=(20,30))

# Variables
size = [50, 500, 5000]
p = 0.15
youdist = [stats.binom(a,p) for a in size]

# Plot each PMF
for x in range(3):
    ran = np.arange(youdist[x].ppf(0.001),
                   youdist[x].ppf(0.999))
    ax[x].plot(ran, youdist[x].pmf(ran))
    ax[x].set_title(f'Size: {size[x]}')

# For visualization reasons, the next discrete distributions are represented using continuous lines

# %% [markdown]
# #### What did you notice from the distribution plots? Comment your findings.

# %% [markdown]
# `Comments:` Las gráficas siempre tienen el punto más alto en n*p.
#
# Por ejemplo, para n = 500, la probabilidad mayor es que 500*0.15 = 75 personas hagan click.

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Reaserch the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %% [markdown]
# `Comments:` Se suele usar para dimensionar en distribuciones que tengan que ver con el tiempo para medir la probabilidad de que un evento ocurra x veces en un lapso de tiempo si éstos se producen de forma independiente y a velocidad constante. Se suele usar en teoría de colas, pero también se usa en lugar de la binomial para eventos en los que la probabilidad es muy pequeña, como por ejemplo en control de calidad.

# %% [markdown]
# #### A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# *Hint: use `scipy.stats.poisson`*

# %%
# Variables
mu = 300
visits = 320

# Probability
stats.poisson(mu).pmf(visits)
# Out:
# 0.011612348610402475

# %% [markdown]
# #### What is the probability of getting 60 visits?

# %%
# Variables
visits = 60

# Probability
stats.poisson(mu).pmf(visits)
# Out:
# 2.622743762294515e-64

# %% [markdown]
# #### Plot the distribution of the probability for getting 0-1000 visits.
#
# *Hints:*
#
# - Create a list to store the Poisson distribution probabilities for n=0 to 1000. Then plot the probabilities.
#
# - Your plot should look like below:
#
# ![poisson distribution](images/ch-3.png)

# %%
_ = [1,2,3,4,5,4,3,6,5,3]
plt.plot(_)

# %%
# Variables
visits = range(1000)

# Plot of the distribution
poislist = [stats.poisson(mu).cdf(x) for x in visits]
_ = plt.plot(poislist)

# %% [markdown]
# # Challenge 4 - Central Limit Theorem
# #### Example of application
#
# A delivery company needs 35 minutes to deliver a package, with a standard deviation of 8 minutes. Suppose that in one day, they deliver 200 packages.
#
# #### a. What is the probability that the mean delivery time today is between 30 and 35 minutes?

# %% [raw]
# Calculamos el standard error.
#
# La distribución de las medias se comportará como las de las observaciones pero la desviación standard será el standard error.
#
# A mayor número muestral, más probabilidades de que las medias tiendan al centro.

# %%
# Variables
mu = 35
sigma = 8
n = 200
se = sigma / np.sqrt(n)     # Calculamos el standard error
pack = stats.norm(mu, se)   # Nuestras distribución normal tiene el standard error como desviación

# Probability
1 - pack.cdf(30) - pack.sf(35)
# Out:
# 0.5

# %% [markdown]
# #### b. What is the probability that in total, it takes more than 115 hours to deliver all 200 packages?

# %%
# Variables
minutesonepack = (115*60) / 200

# Probability
pack.sf(minutesonepack)  # Usamos la misma variable pack porque el standard error es el mismo ya que n = 200
# Out:
# 0.8116204410942089

# %% [markdown]
# # Challenge 5 - Normal Variables
#
# The value (in thousands) of the monthly sales of a publishing company follows a normal distribution with a mean equal to 200 and a standard deviation equal to 40.
#
# <div align="center">$X → N(200,40)$</div>
#
# #### 1. Find the probability that the monthly sales are more than 300.

# %%
# Variables
mu = 200
sigma = 40

# Probability
publ = stats.norm(mu, sigma)
publ.sf(300)
# Out:
# 0.006209665325776132

# %% [markdown]
# #### 2. Find the probability that the monthly sales fall between 160 and 240.

# %%
# Probability

# Como es una variable discreta

1 - publ.sf(240) - publ.cdf(160)
# Out:
# 0.6826894921370859

# %% [markdown]
# #### 3. Find the probability that the monthly sales do not exceed 150.

# %%
# Probability
publ.cdf(150)
# Out:
# 0.10564977366685535

# %% [markdown]
# #### 4. Find the probability that the monthly sales exceed 3000.

# %%
# Probability
publ.sf(3000)
# Out:
# 0.0

# %% [markdown]
# # Challenge 6 - Poisson distribution
# The mean number of violent robberies per month that are registered in a particular barrio is 4. Find the following probabilities.
# #### 1.The probability that in a particular month there is no violent robbery.

# %%
# Variables
mu = 4

# Probability
rob = stats.poisson(mu)
rob.pmf(0)
# Out:
# 0.01831563888873418

# %% [markdown]
# #### 2. The probability that there are at least 1 in a given month.

# %%
# Probability
rob.cdf(1)
# Out:
# 0.0915781944436709

# %% [markdown]
# #### 3. The probability that there are between 2 and 6 (inclusive) in a given month.

# %%
# Probability
1 - rob.cdf(1) - rob.sf(6)
# Out:
# 0.7977478271537555

# %% [markdown]
# #### 4. The probability that there more than two in 15 days.

# %%
# Probability

# Consideramos que el dato que nos da por un mes es de 30 días, luego 15 días es 30/2
rob2 = stats.poisson(mu/2)

rob2.sf(1)
# Out:
# 0.5939941502901616
